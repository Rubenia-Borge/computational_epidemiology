# %%
# Random Walks 2

import random


def random_walk_1_contaminant():
 Total_Times_We_Run=1000

 n=100 # number of random steps to take
 data_question_1 = open("data_question_1.csv","w") # open file for writing
 data_question_1.write("Times,Steps, Step at Infection,Infected, Infection?, X1, Y1, Probability\n") # write headers to file
 data_infected_1 = open("data_infected_1.csv","w")
 data_infected_1.write("Times, Steps,Infected, X1, Y1, Is_Infected\n")

 Infected = 0
 for times in range(1, Total_Times_We_Run + 1):
     Px=50 #x-position
     Py=50 #y-position
     Px2 = 45
     Py2 = 40

     step_at_infection=0
     Is_Infected = "No"
     S=0 #step counter
     probability = 0

     while (S<n): #while we have not yet taken n steps
         data_question_1.write(
             str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected)+","+str(Is_Infected) + "," +str(Px) + "," + str(
                 Py) + ","+ str(probability) + "," + "\n")  # write the final position
         R=random.random()
         if R<0.25:
             Px-=1 #move left
             if Px < 0:
                 Px = 1
             if (Px == Px2) and (Py == Py2):
                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_1.write(str(times)+","+str(S)+","+str(Infected)+","+str(Px)+","+str(Py)+","+str(Is_Infected)+","+"\n")
                 data_question_1.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"
         elif R<0.5:
             Px+=1 #move right
             if Px > 100:
                 Px = 100
             if (Px == Px2) and (Py == Py2):
                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_1.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                 data_question_1.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"

         elif R<0.75:
             Py-=1 #move down
             if Py < 0:
                 Py = 1
             if (Px == Px2) and (Py == Py2):
                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_1.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                 data_question_1.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                Is_Infected = "No"

         else:
             Py+=1 #move up
             if Py > 100:
                 Py = 100

             if (Px == Px2) and (Py == Py2):
                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_1.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                 data_question_1.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"

         S += 1  # update step counter

 data_question_1.close()
 data_infected_1.close()


def random_walk_5_contaminants():
 Total_Times_We_Run=1000

 n=100 # number of random steps to take
 data_question_5 = open("data_question_5.csv","w") # open file for writing
 data_question_5.write("Times,Steps, Step at Infection,Infected, Infection?, X1, Y1, Probability\n") # write headers to file
 data_infected_5 = open("data_infected_5.csv","w")
 data_infected_5.write("Times, Steps,Infected, X1, Y1, Is_Infected\n")

 Infected = 0
 for times in range(1, Total_Times_We_Run + 1):
     Px=50 #x-position
     Py=50 #y-position

     Px2 = 45
     Py2 = 50

     Px3 = 53
     Py3 = 59

     Px4 = 55
     Py4 = 60

     Px5 = 51
     Py5 = 54



     step_at_infection=0
     Is_Infected = "No"
     S=0 #step counter
     probability = 0

     while (S<n): #while we have not yet taken n steps
         data_question_5.write(
             str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected)+","+str(Is_Infected) + "," +str(Px) + "," + str(
                 Py) + ","+ str(probability) + "," + "\n")  # write the final position
         R=random.random()
         if R<0.25:
             Px-=1 #move left
             if Px < 0:
                 Px = 1
             if (((Px == Px2) and (Py == Py2)) or ((Px == Px3) and (Py == Py3)) or ((Px == Px4) and (Py == Py4)) or ((Px == Px5) and (Py == Py5))):
                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_5.write(str(times)+","+str(S)+","+str(Infected)+","+str(Px)+","+str(Py)+","+str(Is_Infected)+","+"\n")
                 data_question_5.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"
         elif R<0.5:
             Px+=1 #move right
             if Px > 100:
                 Px = 100
                 if (((Px == Px2) and (Py == Py2)) or ((Px == Px3) and (Py == Py3)) or (
                         (Px == Px4) and (Py == Py4)) or ((Px == Px5) and (Py == Py5))):
                  Is_Infected = "Yes"
                  Infected = Infected + 1
                  step_at_infection = S
                  probability = Infected / 1000
                  data_infected_5.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                  data_question_5.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"

         elif R<0.75:
             Py-=1 #move down
             if Py < 0:
                 Py = 1
                 if (((Px == Px2) and (Py == Py2)) or ((Px == Px3) and (Py == Py3)) or (
                         (Px == Px4) and (Py == Py4)) or ((Px == Px5) and (Py == Py5))):
                  Is_Infected = "Yes"
                  Infected = Infected + 1
                  step_at_infection = S
                  probability = Infected / 1000
                  data_infected_5.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                  data_question_5.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                Is_Infected = "No"

         else:
             Py+=1 #move up
             if Py > 100:
                 Py = 100

                 if (((Px == Px2) and (Py == Py2)) or ((Px == Px3) and (Py == Py3)) or (
                         (Px == Px4) and (Py == Py4)) or ((Px == Px5) and (Py == Py5))):
                  Is_Infected = "Yes"
                  Infected = Infected + 1
                  step_at_infection = S
                  probability = Infected / 1000
                  data_infected_5.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                  data_question_5.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"

         S += 1  # update step counter

 data_question_5.close()
 data_infected_5.close()






def random_walk_50_contaminants():
 Total_Times_We_Run=1000

 n=100 # number of random steps to take
 data_question_50 = open("data_question_50.csv","w") # open file for writing
 data_question_50.write("Times,Steps, Step at Infection,Infected, Infection?, X1, Y1, Probability\n") # write headers to file
 data_infected_50 = open("data_infected_50.csv","w")
 data_infected_50.write("Times, Steps,Infected, X1, Y1, Is_Infected\n")

 Infected = 0
 for times in range(1, Total_Times_We_Run + 1):
     Px=50 #x-position
     Py=50 #y-position

     Px2 = 45
     Py2 = 50

     Px3 = 53
     Py3 = 61

     Px4 = 45
     Py4 = 50

     Px5 = 51
     Py5 = 54

     Px6 = 49  # x-position
     Py6 = 39  # y-position

     Px7 = 60
     Py7 = 62

     Px8 = 49
     Py8 = 50

     Px9 = 49
     Py9 = 67

     Px10 = 70
     Py10 = 50

     Px11 = 43  # x-position
     Py11 = 49  # y-position

     Px12 = 53
     Py12 = 54

     Px13 = 51
     Py13 = 54

     Px14 = 45
     Py14 = 54

     Px15 = 50
     Py15 = 59

     Px16 = 45 # x-position
     Py16 = 59  # y-position

     Px17 = 61
     Py17 = 60

     Px18 = 44
     Py18 = 51

     Px19 = 21
     Py19 = 59

     Px20 = 52
     Py20 = 52

     Px21 = 59  # x-position
     Py21 = 67  # y-position

     Px22 = 71
     Py22 = 90

     Px23 = 0
     Py23 = 0

     Px24 = 45
     Py24 = 65

     Px25 = 59
     Py25 = 28

     Px26 = 45# x-position
     Py26 = 4  # y-position

     Px27 = 30
     Py27 = 24

     Px28 = 12
     Py28 = 3

     Px29 = 19
     Py29 = 100

     Px30 = 75
     Py30 = 75

     Px31 = 25  # x-position
     Py31 = 25  # y-position

     Px32 = 43
     Py32 = 39

     Px33 = 61
     Py33 = 5

     Px34 = 73
     Py34 = 8

     Px35 = 59
     Py35 = 59

     Px36 = 25  # x-position
     Py36 = 57 # y-position

     Px37 = 69
     Py37 = 10

     Px38 = 11
     Py38 = 77

     Px39 = 83
     Py39 = 3

     Px40 = 88
     Py40 = 94

     Px41 = 47  # x-position
     Py41 = 81 # y-position

     Px42 = 92
     Py42 = 57

     Px43 = 36
     Py43 = 37

     Px44 = 65
     Py44 = 99

     Px45 = 48
     Py45 = 68

     Px46 = 90 # x-position
     Py46 = 46  # y-position

     Px47 = 40
     Py47 = 22

     Px48 = 55
     Py48 = 36

     Px49 = 61
     Py49 = 77

     Px50 = 57
     Py50 = 54



     step_at_infection=0
     Is_Infected = "No"
     S=0 #step counter
     probability = 0

     while (S<n): #while we have not yet taken n steps
         data_question_50.write(
             str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected)+","+str(Is_Infected) + "," +str(Px) + "," + str(
                 Py) + ","+ str(probability) + "," + "\n")  # write the final position
         R=random.random()
         if R<0.25:
             Px-=1 #move left
             if Px < 0:
                 Px = 1
             if (

                     ((Px == Px2) and (Py == Py2)) or ((Px == Px3) and (Py == Py3)) or (
                     (Px == Px4) and (Py == Py4)) or ((Px == Px5) and (Py == Py5)) or

                     ((Px == Px6) and (Py == Py6)) or ((Px == Px7) and (Py == Py7)) or (
                     (Px == Px8) and (Py == Py8)) or ((Px == Px9) and (Py == Py9)) or ((Px == Px10) and (Py == Py10)) or

                     ((Px == Px11) and (Py == Py11)) or ((Px == Px12) and (Py == Py12)) or ((Px == Px13) and (Py == Py13)) or (
                     (Px == Px14) and (Py == Py14)) or ((Px == Px15) and (Py == Py15)) or

                     ((Px == Px16) and (Py == Py16)) or ((Px == Px17) and (Py == Py17)) or (
                     (Px == Px18) and (Py == Py18)) or ((Px == Px19) and (Py == Py19)) or ((Px == Px20) and (Py == Py20)) or

                     ((Px == Px21) and (Py == Py21)) or ((Px == Px22) and (Py == Py22)) or (
                     (Px == Px23) and (Py == Py23)) or ((Px == Px24) and (Py == Py24)) or ((Px == Px25) and (Py == Py25)) or

                     ((Px == Px26) and (Py == Py26)) or ((Px == Px27) and (Py == Py27)) or (
                     (Px == Px28) and (Py == Py28)) or ((Px == Px29) and (Py == Py29)) or ((Px == Px30) and (Py == Py30)) or

                     ((Px == Px31) and (Py == Py31)) or ((Px == Px32) and (Py == Py32)) or (
                     (Px == Px33) and (Py == Py33)) or ((Px == Px34) and (Py == Py34)) or ((Px == Px35) and (Py == Py35)) or

                     ((Px == Px36) and (Py == Py36)) or ((Px == Px37) and (Py == Py37)) or (
                     (Px == Px38) and (Py == Py38)) or ((Px == Px39) and (Py == Py39)) or ((Px == Px40) and (Py == Py40)) or

                     ((Px == Px41) and (Py == Py41)) or ((Px == Px42) and (Py == Py42)) or (
                     (Px == Px43) and (Py == Py43)) or ((Px == Px44) and (Py == Py44)) or ((Px == Px45) and (Py == Py45)) or

                     ((Px == Px46) and (Py == Py46)) or ((Px == Px47) and (Py == Py47)) or (
                     (Px == Px48) and (Py == Py48)) or ((Px == Px49) and (Py == Py49)) or ((Px == Px50) and (Py == Py50))

             ):

                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_50.write(str(times)+","+str(S)+","+str(Infected)+","+str(Px)+","+str(Py)+","+str(Is_Infected)+","+"\n")
                 data_question_50.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"
         elif R<0.5:
             Px+=1 #move right
             if Px > 100:
                 Px = 100
             if (

                     ((Px == Px2) and (Py == Py2)) or ((Px == Px3) and (Py == Py3)) or (
                     (Px == Px4) and (Py == Py4)) or ((Px == Px5) and (Py == Py5)) or

                     ((Px == Px6) and (Py == Py6)) or ((Px == Px7) and (Py == Py7)) or (
                     (Px == Px8) and (Py == Py8)) or ((Px == Px9) and (Py == Py9)) or ((Px == Px10) and (Py == Py10)) or

                     ((Px == Px11) and (Py == Py11)) or ((Px == Px12) and (Py == Py12)) or (
                     (Px == Px13) and (Py == Py13)) or (
                     (Px == Px14) and (Py == Py14)) or ((Px == Px15) and (Py == Py15)) or

                     ((Px == Px16) and (Py == Py16)) or ((Px == Px17) and (Py == Py17)) or (
                     (Px == Px18) and (Py == Py18)) or ((Px == Px19) and (Py == Py19)) or (
                     (Px == Px20) and (Py == Py20)) or

                     ((Px == Px21) and (Py == Py21)) or ((Px == Px22) and (Py == Py22)) or (
                     (Px == Px23) and (Py == Py23)) or ((Px == Px24) and (Py == Py24)) or (
                     (Px == Px25) and (Py == Py25)) or

                     ((Px == Px26) and (Py == Py26)) or ((Px == Px27) and (Py == Py27)) or (
                     (Px == Px28) and (Py == Py28)) or ((Px == Px29) and (Py == Py29)) or (
                     (Px == Px30) and (Py == Py30)) or

                     ((Px == Px31) and (Py == Py31)) or ((Px == Px32) and (Py == Py32)) or (
                     (Px == Px33) and (Py == Py33)) or ((Px == Px34) and (Py == Py34)) or (
                     (Px == Px35) and (Py == Py35)) or

                     ((Px == Px36) and (Py == Py36)) or ((Px == Px37) and (Py == Py37)) or (
                     (Px == Px38) and (Py == Py38)) or ((Px == Px39) and (Py == Py39)) or (
                     (Px == Px40) and (Py == Py40)) or

                     ((Px == Px41) and (Py == Py41)) or ((Px == Px42) and (Py == Py42)) or (
                     (Px == Px43) and (Py == Py43)) or ((Px == Px44) and (Py == Py44)) or (
                     (Px == Px45) and (Py == Py45)) or

                     ((Px == Px46) and (Py == Py46)) or ((Px == Px47) and (Py == Py47)) or (
                     (Px == Px48) and (Py == Py48)) or ((Px == Px49) and (Py == Py49)) or (
                     (Px == Px50) and (Py == Py50))

             ):

                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_50.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                 data_question_50.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"

         elif R<0.75:
             Py-=1 #move down
             if Py < 0:
                 Py = 1
             if (

                     ((Px == Px2) and (Py == Py2)) or ((Px == Px3) and (Py == Py3)) or (
                     (Px == Px4) and (Py == Py4)) or ((Px == Px5) and (Py == Py5)) or

                     ((Px == Px6) and (Py == Py6)) or ((Px == Px7) and (Py == Py7)) or (
                     (Px == Px8) and (Py == Py8)) or ((Px == Px9) and (Py == Py9)) or ((Px == Px10) and (Py == Py10)) or

                     ((Px == Px11) and (Py == Py11)) or ((Px == Px12) and (Py == Py12)) or (
                     (Px == Px13) and (Py == Py13)) or (
                     (Px == Px14) and (Py == Py14)) or ((Px == Px15) and (Py == Py15)) or

                     ((Px == Px16) and (Py == Py16)) or ((Px == Px17) and (Py == Py17)) or (
                     (Px == Px18) and (Py == Py18)) or ((Px == Px19) and (Py == Py19)) or (
                     (Px == Px20) and (Py == Py20)) or

                     ((Px == Px21) and (Py == Py21)) or ((Px == Px22) and (Py == Py22)) or (
                     (Px == Px23) and (Py == Py23)) or ((Px == Px24) and (Py == Py24)) or (
                     (Px == Px25) and (Py == Py25)) or

                     ((Px == Px26) and (Py == Py26)) or ((Px == Px27) and (Py == Py27)) or (
                     (Px == Px28) and (Py == Py28)) or ((Px == Px29) and (Py == Py29)) or (
                     (Px == Px30) and (Py == Py30)) or

                     ((Px == Px31) and (Py == Py31)) or ((Px == Px32) and (Py == Py32)) or (
                     (Px == Px33) and (Py == Py33)) or ((Px == Px34) and (Py == Py34)) or (
                     (Px == Px35) and (Py == Py35)) or

                     ((Px == Px36) and (Py == Py36)) or ((Px == Px37) and (Py == Py37)) or (
                     (Px == Px38) and (Py == Py38)) or ((Px == Px39) and (Py == Py39)) or (
                     (Px == Px40) and (Py == Py40)) or

                     ((Px == Px41) and (Py == Py41)) or ((Px == Px42) and (Py == Py42)) or (
                     (Px == Px43) and (Py == Py43)) or ((Px == Px44) and (Py == Py44)) or (
                     (Px == Px45) and (Py == Py45)) or

                     ((Px == Px46) and (Py == Py46)) or ((Px == Px47) and (Py == Py47)) or (
                     (Px == Px48) and (Py == Py48)) or ((Px == Px49) and (Py == Py49)) or (
                     (Px == Px50) and (Py == Py50))

             ):

                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_50.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                 data_question_50.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                Is_Infected = "No"

         else:
             Py+=1 #move up
             if Py > 100:
                 Py = 100

             if (

                     ((Px == Px2) and (Py == Py2)) or ((Px == Px3) and (Py == Py3)) or (
                     (Px == Px4) and (Py == Py4)) or ((Px == Px5) and (Py == Py5)) or

                     ((Px == Px6) and (Py == Py6)) or ((Px == Px7) and (Py == Py7)) or (
                     (Px == Px8) and (Py == Py8)) or ((Px == Px9) and (Py == Py9)) or ((Px == Px10) and (Py == Py10)) or

                     ((Px == Px11) and (Py == Py11)) or ((Px == Px12) and (Py == Py12)) or (
                     (Px == Px13) and (Py == Py13)) or (
                     (Px == Px14) and (Py == Py14)) or ((Px == Px15) and (Py == Py15)) or

                     ((Px == Px16) and (Py == Py16)) or ((Px == Px17) and (Py == Py17)) or (
                     (Px == Px18) and (Py == Py18)) or ((Px == Px19) and (Py == Py19)) or (
                     (Px == Px20) and (Py == Py20)) or

                     ((Px == Px21) and (Py == Py21)) or ((Px == Px22) and (Py == Py22)) or (
                     (Px == Px23) and (Py == Py23)) or ((Px == Px24) and (Py == Py24)) or (
                     (Px == Px25) and (Py == Py25)) or

                     ((Px == Px26) and (Py == Py26)) or ((Px == Px27) and (Py == Py27)) or (
                     (Px == Px28) and (Py == Py28)) or ((Px == Px29) and (Py == Py29)) or (
                     (Px == Px30) and (Py == Py30)) or

                     ((Px == Px31) and (Py == Py31)) or ((Px == Px32) and (Py == Py32)) or (
                     (Px == Px33) and (Py == Py33)) or ((Px == Px34) and (Py == Py34)) or (
                     (Px == Px35) and (Py == Py35)) or

                     ((Px == Px36) and (Py == Py36)) or ((Px == Px37) and (Py == Py37)) or (
                     (Px == Px38) and (Py == Py38)) or ((Px == Px39) and (Py == Py39)) or (
                     (Px == Px40) and (Py == Py40)) or

                     ((Px == Px41) and (Py == Py41)) or ((Px == Px42) and (Py == Py42)) or (
                     (Px == Px43) and (Py == Py43)) or ((Px == Px44) and (Py == Py44)) or (
                     (Px == Px45) and (Py == Py45)) or

                     ((Px == Px46) and (Py == Py46)) or ((Px == Px47) and (Py == Py47)) or (
                     (Px == Px48) and (Py == Py48)) or ((Px == Px49) and (Py == Py49)) or (
                     (Px == Px50) and (Py == Py50))

             ):

                 Is_Infected = "Yes"
                 Infected = Infected + 1
                 step_at_infection = S
                 probability = Infected / 1000
                 data_infected_50.write(
                     str(times) + "," + str(S) + "," + str(Infected) + "," + str(Px) + "," + str(Py) + "," + str(
                         Is_Infected) + "," + "\n")
                 data_question_50.write(
                     str(times) + "," + str(S) + "," + str(step_at_infection) + "," + str(Infected) + "," + str(
                         Is_Infected) + "," + str(Px) + "," + str(
                         Py) + "," + str(probability) + "," + "\n")  # write the final position
             else:
                 Is_Infected = "No"

         S += 1  # update step counter

 data_question_50.close()
 data_infected_50.close()

# Driver Code

random_walk_1_contaminant()
random_walk_5_contaminants()
random_walk_50_contaminants()
print('Program finished. Please check csv files generated for results.')
